# %% [markdown]
# # Purpose
# The purpose of this notebook is to get an introduction to reinforcement learning (RL).
#
# ## Step 1: Dependencies
#  - Stable Baselines is a library to make RL easier. Think of it as the tensorflow of RL. It was based off of baselines, a package that was developed by OpenAI
#  - Gym is another package created by OpenAI. It provides a variety of environments

# %%
# !pip install stable-baselines3[extra] gymnasium tensorflow tensorboard
# Out:
# Collecting stable-baselines3[extra]
#   Obtaining dependency information for stable-baselines3[extra] from https://files.pythonhosted.org/packages/d9/57/13d4e4b7bbbc940815964ac31e205263b8133f1f2a0147bd4ca884a6e174/stable_baselines3-2.0.0-py3-none-any.whl.metadata
#   Using cached stable_baselines3-2.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting gymnasium
#   Obtaining dependency information for gymnasium from https://files.pythonhosted.org/packages/3f/00/a728a4a8608213482fc38d76d842657d29b546f214e83801a044de074612/gymnasium-0.29.0-py3-none-any.whl.metadata
#   Downloading gymnasium-0.29.0-py3-none-any.whl.metadata (10 kB)
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/ba/7c/b971f2485155917ecdcebb210e021e36a6b65457394590be01cc61515310/tensorflow-2.13.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorboard
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting gymnasium
#   Using cached gymnasium-0.28.1-py3-none-any.whl (925 kB)
# Collecting numpy>=1.20 (from stable-baselines3[extra])
#   Obtaining dependency information for numpy>=1.20 from https://files.pythonhosted.org/packages/b7/db/4d37359e2c9cf8bf071c08b8a6f7374648a5ab2e76e2e22e3b808f81d507/numpy-1.25.2-cp310-cp310-win_amd64.whl.metadata
#   Using cached numpy-1.25.2-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Collecting torch>=1.11 (from stable-baselines3[extra])
#   Using cached torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
# Collecting cloudpickle (from stable-baselines3[extra])
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting pandas (from stable-baselines3[extra])
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ed/30/b97456e7063edac0e5a405128065f0cd2033adfe3716fb2256c186bd41d0/pandas-2.0.3-cp310-cp310-win_amd64.whl.metadata
#   Using cached pandas-2.0.3-cp310-cp310-win_amd64.whl.metadata (18 kB)
# Collecting matplotlib (from stable-baselines3[extra])
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/ff/1f/2b83c7acf453318a80dc619e99fc30a663b2c1fb18be3d358a96addfecd9/matplotlib-3.7.2-cp310-cp310-win_amd64.whl.metadata
#   Using cached matplotlib-3.7.2-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting opencv-python (from stable-baselines3[extra])
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/a6/08/583e1d8d589e80a702815f58daa317bd469a32c7dc339394e2a0dc14318b/opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: psutil in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from stable-baselines3[extra]) (5.9.5)
# Collecting tqdm (from stable-baselines3[extra])
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting rich (from stable-baselines3[extra])
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/8d/5f/21a93b2ec205f4b79853ff6e838e3c99064d5dbe85ec6b05967506f14af0/rich-13.5.2-py3-none-any.whl.metadata
#   Using cached rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Collecting shimmy[atari]~=0.2.1 (from stable-baselines3[extra])
#   Using cached Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting pillow (from stable-baselines3[extra])
#   Obtaining dependency information for pillow from https://files.pythonhosted.org/packages/d0/4f/faebe1180e5e6ad6330c539dda7f6081182157393ba6816a438f759a0e59/Pillow-10.0.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached Pillow-10.0.0-cp310-cp310-win_amd64.whl.metadata (9.6 kB)
# Collecting autorom[accept-rom-license]~=0.6.0 (from stable-baselines3[extra])
#   Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/e8/e2/8bb32810016a24780bd2b26f3c7c2e4fba7d06e33aeb1ed9ac847fb10424/pygame-2.5.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached pygame-2.5.0-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting jax-jumpy>=1.0.0 (from gymnasium)
#   Using cached jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium)
#   Obtaining dependency information for typing-extensions>=4.3.0 from https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting tensorflow-intel==2.13.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.13.0 from https://files.pythonhosted.org/packages/40/fa/98115f6fe4d92e1962f549917be2dc8e369853b7e404191996fedaaf4dd6/tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.1.21 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for flatbuffers>=23.1.21 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/e2/c4/6f8dae1530d57a6122fd5b72c750187484acbe612f630cb2179e4bcb12c1/h5py-3.9.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached h5py-3.9.0-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/02/8c/dc970bc00867fe290e8c8a7befa1635af716a9ebdfe3fb9dce0ca4b522ce/libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting numpy>=1.20 (from stable-baselines3[extra])
#   Using cached numpy-1.24.3-cp310-cp310-win_amd64.whl (14.8 MB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/80/70/dc63d340d27b8ff22022d7dd14b8d6d68b479a003eacdc4507150a286d9a/protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata
#   Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/3f/fe/b332c682f682745230083023935a06f21e029cb8ef01900531a89b47217c/grpcio-1.56.2-cp310-cp310-win_amd64.whl.metadata
#   Using cached grpcio-1.56.2-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.14,>=2.13.0 from https://files.pythonhosted.org/packages/72/5c/c318268d96791c6222ad7df1651bbd1b2409139afeb6f468c0f327177016/tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/9c/8d/bff87fc722553a5691d8514da5523c23547f3894189ba03b57592e37bdc2/google_auth-2.22.0-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.22.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/1a/b5/228c1cdcfe138f1a8e01ab1b54284c8b83735476cb22b6ba251656ed13ad/Markdown-3.4.4-py3-none-any.whl.metadata
#   Using cached Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard)
#   Obtaining dependency information for requests<3,>=2.21.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/ba/d6/8040faecaba2feb84e1647af174b3243c9b90c163c7ea407820839931efe/Werkzeug-2.3.6-py3-none-any.whl.metadata
#   Using cached Werkzeug-2.3.6-py3-none-any.whl.metadata (4.1 kB)
# Collecting wheel>=0.26 (from tensorboard)
#   Obtaining dependency information for wheel>=0.26 from https://files.pythonhosted.org/packages/28/f5/6955d7b3a5d71ce6bac104f9cf98c1b0513ad656cdaca8ea7d579196f771/wheel-0.41.1-py3-none-any.whl.metadata
#   Using cached wheel-0.41.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting click (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra])
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/1a/70/e63223f8116931d365993d4a6b7ef653a4d920b41d03de7c59499962821f/click-8.1.6-py3-none-any.whl.metadata
#   Using cached click-8.1.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra])
#   Using cached AutoROM.accept_rom_license-0.6.1-py3-none-any.whl
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Using cached cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<2.0 (from google-auth<3,>=1.6.3->tensorboard)
#   Obtaining dependency information for urllib3<2.0 from https://files.pythonhosted.org/packages/c5/05/c214b32d21c0b465506f95c4f28ccbcba15022e000b043b72b3df7728471/urllib3-1.26.16-py2.py3-none-any.whl.metadata
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl.metadata (48 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/5c/f2/f3faa20684729d3910af2ee142e30432c7a46a817eadeeab87366ed87bbb/charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=0.2.1->stable-baselines3[extra])
#   Using cached ale_py-0.8.1-cp310-cp310-win_amd64.whl (952 kB)
# Collecting filelock (from torch>=1.11->stable-baselines3[extra])
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/00/45/ec3407adf6f6b5bf867a4462b2b0af27597a26bd3cd6e2534cb6ab029938/filelock-3.12.2-py3-none-any.whl.metadata
#   Using cached filelock-3.12.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting sympy (from torch>=1.11->stable-baselines3[extra])
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch>=1.11->stable-baselines3[extra])
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting jinja2 (from torch>=1.11->stable-baselines3[extra])
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard)
#   Obtaining dependency information for MarkupSafe>=2.1.1 from https://files.pythonhosted.org/packages/84/a8/c4aebb8a14a1d39d5135eb8233a0b95831cdc42c4088358449c3ed657044/MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl.metadata
#   Using cached MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->stable-baselines3[extra])
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/94/0a/5eb57dd395fade977786b2d2c98c2bee8234358794be44422fe58a719d42/contourpy-1.1.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached contourpy-1.1.0-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Collecting cycler>=0.10 (from matplotlib->stable-baselines3[extra])
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable-baselines3[extra])
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/8e/8a/2780329735ae21d7624f174616407aea106e19b149c46e7efbf2073d62f9/fonttools-4.42.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached fonttools-4.42.0-cp310-cp310-win_amd64.whl.metadata (153 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib->stable-baselines3[extra])
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib->stable-baselines3[extra])
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->stable-baselines3[extra])
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas->stable-baselines3[extra])
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->stable-baselines3[extra])
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: colorama in c:\users\doggi\desktop\pp\reinforcementlearning\introrl\.venv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra])
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/25/d4/592f53ce2f8dde8be5720851bd0ab71cc2e76c55978e4163ef1ab7e389bb/importlib_resources-6.0.1-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.0.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra])
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.11->stable-baselines3[extra])
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl (276.5 MB)
# Using cached google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
# Using cached grpcio-1.56.2-cp310-cp310-win_amd64.whl (4.2 MB)
# Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Using cached Werkzeug-2.3.6-py3-none-any.whl (242 kB)
# Using cached wheel-0.41.1-py3-none-any.whl (64 kB)
# Using cached matplotlib-3.7.2-cp310-cp310-win_amd64.whl (7.5 MB)
# Using cached Pillow-10.0.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
# Using cached pandas-2.0.3-cp310-cp310-win_amd64.whl (10.7 MB)
# Using cached pygame-2.5.0-cp310-cp310-win_amd64.whl (10.5 MB)
# Using cached rich-13.5.2-py3-none-any.whl (239 kB)
# Using cached stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
# Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl (96 kB)
# Using cached contourpy-1.1.0-cp310-cp310-win_amd64.whl (470 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.42.0-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached h5py-3.9.0-cp310-cp310-win_amd64.whl (2.7 MB)
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Using cached click-8.1.6-py3-none-any.whl (97 kB)
# Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Installing collected packages: pytz, mpmath, libclang, flatbuffers, farama-notifications, wrapt, wheel, urllib3, tzdata, typing-extensions, tqdm, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, sympy, pyparsing, pygame, pyasn1, protobuf, pillow, oauthlib, numpy, networkx, mdurl, MarkupSafe, markdown, kiwisolver, keras, importlib-resources, idna, grpcio, google-pasta, gast, fonttools, filelock, cycler, cloudpickle, click, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, pandas, opt-einsum, opencv-python, markdown-it-py, jinja2, jax-jumpy, h5py, contourpy, astunparse, ale-py, torch, rich, requests-oauthlib, matplotlib, gymnasium, google-auth, AutoROM.accept-rom-license, autorom, stable-baselines3, shimmy, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed AutoROM.accept-rom-license-0.6.1 MarkupSafe-2.1.3 absl-py-1.4.0 ale-py-0.8.1 astunparse-1.6.3 autorom-0.6.1 cachetools-5.3.1 certifi-2023.7.22 charset-normalizer-3.2.0 click-8.1.6 cloudpickle-2.2.1 contourpy-1.1.0 cycler-0.11.0 farama-notifications-0.0.4 filelock-3.12.2 flatbuffers-23.5.26 fonttools-4.42.0 gast-0.4.0 google-auth-2.22.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.56.2 gymnasium-0.28.1 h5py-3.9.0 idna-3.4 importlib-resources-6.0.1 jax-jumpy-1.0.0 jinja2-3.1.2 keras-2.13.1 kiwisolver-1.4.4 libclang-16.0.6 markdown-3.4.4 markdown-it-py-3.0.0 matplotlib-3.7.2 mdurl-0.1.2 mpmath-1.3.0 networkx-3.1 numpy-1.24.3 oauthlib-3.2.2 opencv-python-4.8.0.74 opt-einsum-3.3.0 pandas-2.0.3 pillow-10.0.0 protobuf-4.23.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 pygame-2.5.0 pyparsing-3.0.9 pytz-2023.3 requests-2.31.0 requests-oauthlib-1.3.1 rich-13.5.2 rsa-4.9 shimmy-0.2.1 stable-baselines3-2.0.0 sympy-1.12 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-intel-2.13.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0 torch-2.0.1 tqdm-4.65.0 typing-extensions-4.5.0 tzdata-2023.3 urllib3-1.26.16 werkzeug-2.3.6 wheel-0.41.1 wrapt-1.15.0

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np

# %% [markdown]
#  - PPO is one of many RL algorithms. It stands for Proximal Policy Optimization. After an update, the new policy should be slightly different from the old policy
#  - DummyVecEnv is a wrapper around the environment to make it easier to work with Stable Baselines. We are able to use this because we are not vectorizing our environment
#  - evaluate_policy helps us evaluate our model, including the average reward over a certain number of episodes, and the standard deviation

# %% [markdown]
# ## Step 2: Load Environment

# %% [markdown]
# OpenAI gym is a nice way to use a simulated environment. Simulated environments are helpful as they are cheap, fast, easy, and cannot cause real world damage. For example, it is a lot better to train a self driving car in a simulated environment first, before deploying it on the road
#
# For this first example, we will be using the CartPole environment. This is a simple env of balancing a pole on a moving cart

# %%
env_name = 'CartPole-v1'
render_mode = 'human'

# %% [markdown]
# Now that we have loaded the env, let's take a look at it before we do anything more

# %%
env = gym.make(env_name, render_mode = render_mode)

episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        #Visualize the env
        env.render()
        #Create a random action
        action = env.action_space.sample()
        #Pass in our random action to the environment, and collect observations
        #Dummy is pointless
        n_state, reward, done, dummy, info = env.step(action)
        #Add to the score
        score += reward
    print(f'Episode:{episode} Score:{score}')
env.close()
# Out:
# Episode:1 Score:21.0
# Episode:2 Score:26.0
# Episode:3 Score:13.0
# Episode:4 Score:11.0
# Episode:5 Score:20.0

# %% [markdown]
# - Episode: An episode is essentially one full game within an environment. For some games, this is defined when the game ends, such as if a player dies or run out of lives. For cartpole, the episode is defined as surviving 500 frames.
# - State: This is the initial set of observations. The observations are from the environment. These observations will be passed into the agent, to determine the best possible reward.
# - env.render(): This allows us to view what is happening in the environment
# - action: We are generating a random action, not one that is actually useful yet
# - env.step(): Here we are passing in our action into the environment. We get the observations returned.
#
# Note that there are two different spaces, the action space and the environment space
#  - environment space: the observations about the environment
#  - action space: the actions that can be taken

# %%
#This is the different actions that can be taken. Discrete 2 means that there are only two uniquely discrete options that can be taken
print(env.action_space)
#This number will either be a 0 or a 1. This is the random action that is being chosen. This correlates to the cart being moved either left or right
print(env.action_space.sample())
#This is the space that our observations will be saved in. These are the ranges that the 4 numbers can be between
print(env.observation_space)
#This is an example of the results from our observation space
print(env.observation_space.sample())
# Out:
# Discrete(2)
# 1
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# [ 2.4412444e+00  1.7722344e+38  1.1473202e-01 -2.6802146e+38]

# %% [markdown]
# Here's what the numbers in the observation space represent
#  - Number 1: Cart Position
#  - Number 2: Cart Velocity
#  - Number 3: Pole Angle
#  - Number 4: Pole Angular Velocity
#
# See more: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %% [markdown]
# ## Step 3: Training

# %% [markdown]
# It is important to understand our training metrics. There are 3 main types of metrics, as well as other metrics
#
# Evaluation Metrics: These have to do with each episode
# - ep_len_mean: average length of each episode, essentially the length of one game
# - ep_rew_mean: average reward for each episode
#
# Time Metrics: These all have to do with the time
# - fps
# - iterations
# - time_elapsed
# - total_timesteps
#
# Loss Metrics:
# - Entropy_loss
# - policy_loss
# - value_loss
#
# Other Metrics:
# - Explained_variance
# - Learning_rate
# - n_updates

# %%
log_path = os.path.join('Training', 'Logs')

# %%
train_env = gym.make(env_name)
train_env = DummyVecEnv([lambda: train_env])
model = PPO('MlpPolicy', train_env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device

# %% [markdown]
# - policy: the rules that which an agent can follow within a given environment
# - timestep: essentially a frame. A decision point where the agent reads the observations and makes its next action
#     * Note that 20,000 timesteps is considered low
#
# Now, it's time to train our agent. This requires little code. The number of timesteps is specified to train on, not the number of episodes

# %%
#This cell can be run many times, to train the model further
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_10
# -----------------------------
# | time/              |      |
# |    fps             | 1109 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004228264 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.524       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 8.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002756763 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005772123 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 7.46        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006222469 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 4.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008738771 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.618       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004821933 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.716       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0065090843 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0193       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 0.436        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0033387444 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00141     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 10           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0074141435 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.0651       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0433       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 0.177        |
# ------------------------------------------

# %% [markdown]
# ## Step 4: Save and Reload Model

# %%
#Defining the path to save our model to
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_CartPole')

# %%
#Saving the model
model.save(PPO_Path)

# %%
#Deleting the model from memory
del model

# %%
#Reloading in the model
#Must pass in save path and environment
model = PPO.load(PPO_Path, env=env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #Reloading in the model
#       2 #Must pass in save path and environment
# ----> 3 model = PPO.load(PPO_Path, env=env)
#
# NameError: name 'PPO_Path' is not defined

# %% [markdown]
# ## Step 5: Evaluate

# %% [markdown]
# We did not want to render the model during training, as it makes it significantly slower to train. However, we do want to render it during evaluation, so we can actually see the performance of the model. To do this, we will evaluate in a new env from the one we trained in

# %%
#Create evaluation env
eval_env = gym.make(env_name, render_mode='human')
#Load in our model with our evaluation environment
model = PPO.load(PPO_Path, env = eval_env)

#Running the evaluation of the model
evaluate_policy(model, eval_env, n_eval_episodes=10, render=True)

eval_env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\doggi\Desktop\PP\reinforcementLearning\introRL\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ## Step 6: Test Model
#
# Now, we will deploy our model

# %%
test_env = gym.make(env_name, render_mode = render_mode)

episodes = 5
for episode in range(1, episodes+1):
    done = False
    score = 0
    obs = test_env.reset()[0]

    while not done:
        #Visualize the test_env
        test_env.render()

        # Using our model to predict the next action
        action, _ = model.predict(obs)

        #Pass in our action to the environment, and collect observations
        obs, reward, done, done, info = test_env.step(action)
        #Add to the score
        score += reward
    print(f'Episode:{episode} Score:{score}') 

test_env.close()
# Out:
# Episode:1 Score:500.0
# Episode:2 Score:500.0
# Episode:3 Score:500.0
# Episode:4 Score:500.0
# Episode:5 Score:500.0

# %%
test_env.close()

# %% [markdown]
# ## Step 7: Viewing logs in TensorBoard
#
# This will open up analytics about our model. View these by running the tensorboard cell (cell 3), and navigating to localhost:6006

# %%
training_log_path = os.path.join(log_path, 'PPO_9')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_9'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# Note that these are the most important statistics:
# - average_reward
# - average_episode_length
#
# If the model is not meeting expecations, follow these strategies:
# - train longer
# - Hyperparameter tuning
# - try different algorithms

# %% [markdown]
# ## Step 8: Adding a callback to the training Stage
#
# Callbacks allow for intervention during the training stage. For example, if the reward is deemed to be high enough (the agent is good), the model can stop training. Custom actions can be linked to these interventions

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
cb_env = gym.make(env_name)
cb_env = DummyVecEnv([lambda : cb_env])

# %% [markdown]
# - stop_callback: This will stop our training once a certain reward is reached
# - eval_callback: This will run an evaluation on the model. It only runs a certain number of timesteps, in this case, 10000.
#     It will save the model at this callback. We must also pass in our env, and any other callbacks

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(
    cb_env,
    callback_on_new_best = stop_callback,
    eval_freq=10000,
    best_model_save_path=save_path,
    verbose=1
)

# %% [markdown]
# Now that we have these callbacks, let's retrain the agent using them

# %%
model = PPO('MlpPolicy', cb_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 1227 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009362006 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.00634     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.23        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 50          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009828515 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.076       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 39.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 843        |
# |    iterations           | 4          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01050829 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.249      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.6       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0204    |
# |    value_loss           | 53.8       |
# ----------------------------------------
# c:\Users\doggi\Desktop\PP\reinforcementLearning\introRL\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=236.20 +/- 71.40
# Episode length: 236.20 +/- 71.40
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 236          |
# |    mean_reward          | 236          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0076094978 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.616       |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 73.4         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 791   |
# |    iterations      | 5     |
# |    time_elapsed    | 12    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0070579536 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.603       |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.1         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 64.4         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 811        |
# |    iterations           | 7          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00629153 |
# |    clip_fraction        | 0.0414     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.462      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.9       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 66         |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0051879436 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.93         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00735     |
# |    value_loss           | 28.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005943956 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.35        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 27.5        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=493.60 +/- 12.80
# Episode length: 493.60 +/- 12.80
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 494          |
# |    mean_reward          | 494          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0042215674 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.86         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00751     |
# |    value_loss           | 24.8         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 796   |
# |    iterations      | 10    |
# |    time_elapsed    | 25    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## Step 9: Changing Policies
# Let's try running cartpole with a different architecture.
# <br>
# We'll start by defining a new architecture for a neural net
# The pi param specifies the architecture for the actor. It is 4 layers, each consisting of 128 nodes
# The vf param stands for value function. It uses the same arch as the actor

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', cb_env, verbose=1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device
# c:\Users\doggi\Desktop\PP\reinforcementLearning\introRL\.venv\lib\site-packages\stable_baselines3\common\policies.py:460: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1241 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014296461 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.00942     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017592084 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 664        |
# |    iterations           | 4          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01348628 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.6       |
# |    explained_variance   | 0.38       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.3       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0207    |
# |    value_loss           | 41.1       |
# ----------------------------------------
# c:\Users\doggi\Desktop\PP\reinforcementLearning\introRL\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=9520, episode_reward=437.00 +/- 87.57
# Episode length: 437.00 +/- 87.57
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 437         |
# |    mean_reward          | 437         |
# | time/                   |             |
# |    total_timesteps      | 9520        |
# | train/                  |             |
# |    approx_kl            | 0.007967362 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 38.9        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 588   |
# |    iterations      | 5     |
# |    time_elapsed    | 17    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011458071 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 17.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0059748664 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00603     |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007391789 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.966       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 9            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0073857727 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.499       |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.75         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 6.44         |
# ------------------------------------------
# Eval num_timesteps=19520, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 19520       |
# | train/                  |             |
# |    approx_kl            | 0.010572661 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 10.1        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %% [markdown]
# ## Step 10: Changing Algorithms
#
# Let's try using a separate algorithm than PPO

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', cb_env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6358     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5298     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6131     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5373     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5524     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 370      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5340     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 446      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5565     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 509      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4973     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 756      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4707     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4694     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 939      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4530     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4490     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4425     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4390     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4242     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4203     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4219     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.22     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4232     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4186     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.138    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4099     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0804   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4150     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4161     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4188     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4212     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4258     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4219     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4208     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4261     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4256     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4349     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4399     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4395     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4464     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4545     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4608     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4637     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4595     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4582     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4561     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4567     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4515     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4491     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4462     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4461     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4269     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4470     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4452     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4474     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4463     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4435     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4449     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4500     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4488     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4501     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4539     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4563     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4588     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4601     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4631     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4649     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4682     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4722     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4752     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4773     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4820     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4828     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4823     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4846     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4852     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4850     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4831     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4811     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4843     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4815     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4819     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4856     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4889     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4905     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4934     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4996     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5010     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5035     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5081     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7976     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5119     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5172     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5187     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5219     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5238     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5259     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5292     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5306     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5325     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5342     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5371     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5384     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5412     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5415     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5417     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5449     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9568     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5432     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5464     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5467     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5473     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5463     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9998     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5317     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5333     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5344     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5381     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5410     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5405     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5408     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10812    |
# ----------------------------------
# c:\Users\doggi\Desktop\PP\reinforcementLearning\introRL\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5398     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5387     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5347     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5345     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5331     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5336     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5309     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5303     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 5308     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 5300     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 5302     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 5329     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 5332     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 5338     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 5357     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 5370     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 5372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 5370     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 5372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 5360     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 5373     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 5385     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 5397     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 5424     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 5454     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 5462     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 5501     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 5503     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 5511     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 5537     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 5546     |
# |    time_elapsed     | 2        |
# ...
# |    fps              | 5845     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 5869     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 5872     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 5899     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 5902     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 5927     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 5915     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 5941     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 5942     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 5959     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 5987     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 6011     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 6037     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 6045     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 6074     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 6083     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 6100     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 6106     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 6132     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 6124     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 6121     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 6152     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 6158     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 6174     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 6184     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 6182     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 6191     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 6204     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 6213     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 6221     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 6236     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 6198     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 6205     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 6213     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 6208     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 6218     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 6229     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 6222     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 6211     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 6200     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 6204     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 6194     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 6201     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 6195     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 6185     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 6193     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 6213     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 6241     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 6247     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 6257     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19950    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=8.80 +/- 0.40
# Episode length: 8.80 +/- 0.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 8.8      |
# |    mean_reward      | 8.8      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)
